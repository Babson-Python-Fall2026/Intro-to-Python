# %% [markdown]
# # Class 02 — Using AI Well
# **OIM 3600 — Computational Thinking with AI and Python**
#
# In this notebook you will practice the same task three ways:
#
# | Attempt | What you do |
# |---------|-------------|
# | **Lazy** | Paste the problem into Claude with no setup — just the bare question |
# | **Better** | Name the function, types, and expected output before you hit send |
# | **Directed** | Sketch the logic yourself first, decide edge cases, *then* tell Claude exactly what to build |
#
# For each exercise: copy the prompt into Claude, paste the response into the markdown cell, run the code cell below it.
#
# ---

# %% [markdown]
# ## Exercise 1 — Compound Interest
#
# **The problem:** Write a Python function that calculates compound interest.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt into Claude exactly as written.

# %%
# ── PROMPT (copy everything between the quotes into Claude) ──────────────
# "Write a Python function for compound interest."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's code here and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Write a Python function called compound_interest(principal, annual_rate, years, n)
#  where principal is a float (starting amount), annual_rate is a float (e.g. 0.05 for 5%),
#  years is an int, and n is an int (compounding periods per year).
#  Return the final balance as a float rounded to 2 decimal places.
#  Include a docstring with one worked example showing inputs and output."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's code here and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# Before writing your prompt, answer these three questions in the markdown cell below.
# Then write a prompt that reflects your answers — Claude should get all three decisions from you, not guess.
#
# **Questions to answer first:**
# 1. What is the compound interest formula? Write it out: A = ?
# 2. If `n = 0` (zero compounding periods), should the function raise a `ValueError` or return the principal unchanged?
# 3. If `years = 0`, what should the function return?

# %% [markdown]
# **My answers before prompting:**
#
# 1. Formula: A =
# 2. If n = 0:
# 3. If years = 0:
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and run the best version of the function here

# %% [markdown]
# **Reflection:** Compare the three outputs. The lazy prompt left all decisions to Claude. The better prompt named the parameters. Your directed prompt encoded your logic. Which one would you trust in a real project — and why?
#
# ---

# %% [markdown]
# ## Exercise 2 — Explain This Error
#
# **The problem:** Your program crashes. Ask Claude to help.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt — just the error, nothing else.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "ZeroDivisionError: division by zero  — what does this mean?"

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste any code Claude suggests and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "I am writing a Python grade calculator. `count` holds the number of assignments
#  a student submitted; `total` holds the sum of their scores. When count is 0 the
#  program crashes with:
#
#      ZeroDivisionError: division by zero   (grades.py, line 12: average = total / count)
#
#  Explain the cause and show a fix that handles the zero-submission case."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's fixed code and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# Before prompting, decide exactly what the program should do when a student submits nothing.
# Pick one and explain your reasoning in the cell below, then write a prompt that gives Claude your decision.
#
# **Options to choose from:**
# - Return `0` (treat missing submissions as a zero)
# - Return `None` (signal that no grade exists)
# - Raise a `ValueError` with a descriptive message
# - Return a default string like `'N/A'`

# %% [markdown]
# **My decision and why:**
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and run the fixed code here

# %% [markdown]
# **Reflection:** The lazy prompt got a generic explanation. The better prompt got a contextual fix. Your directed prompt encoded a *policy decision* that Claude cannot guess. What happens downstream in a real system if Claude guesses wrong?
#
# ---

# %% [markdown]
# ## Exercise 3 — Clean This Data
#
# **The problem:** A list of student score strings has whitespace, empty strings, and 'N/A' values mixed in.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt — one verb, no context.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Clean this list: ["92", "85 ", " 78", "N/A", "91", "", "88", "n/a", "76"]"

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's code here and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Write a Python function called clean_scores(raw) that takes a list of strings
#  and returns a list of integers. Strip whitespace, skip empty strings and any
#  case-insensitive variant of 'N/A'. Show the result for this input:
#  ["92", "85 ", " 78", "N/A", "91", "", "88", "n/a", "76"]"

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's code here and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# The word 'clean' is ambiguous — Claude will interpret it however it wants unless you decide first.
# Answer these two questions before you write your prompt:
#
# 1. When an entry is invalid (empty, 'N/A', non-numeric), should the function **skip it silently**, **log it to the console**, or **raise a ValueError**?
# 2. Should the function also validate that valid scores fall between 0 and 100, or just convert and return?

# %% [markdown]
# **My decisions:**
#
# 1. Invalid entries:
# 2. Range validation:
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and run the best version here
scores = ["92", "85 ", " 78", "N/A", "91", "", "88", "n/a", "76"]
# call your function below

# %% [markdown]
# **Reflection:** The lazy prompt got *something* — but was it what you actually needed? Count how many design decisions Claude made silently in the lazy response. Each one is a place where the code could quietly do the wrong thing.
#
# ---

# %% [markdown]
# ## Exercise 4 — Write a Docstring
#
# **The problem:** Add a docstring to this function.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt with the function.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Add a docstring to this function."

# ── Function to paste along with the prompt ───────────────────────────────
def grade_letter(score):
    if score >= 90: return 'A'
    elif score >= 80: return 'B'
    elif score >= 70: return 'C'
    elif score >= 60: return 'D'
    else: return 'F'

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's version here and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Add a Google-style docstring to this function. Include:
#  - a one-line summary
#  - an Args section: parameter name, type, and valid range
#  - a Returns section: type and what value maps to what letter
#  - one Example block showing a call and its output
#  Do not change the function body — only add the docstring."

# ── Function to paste along with the prompt ───────────────────────────────
def grade_letter(score):
    if score >= 90: return 'A'
    elif score >= 80: return 'B'
    elif score >= 70: return 'C'
    elif score >= 60: return 'D'
    else: return 'F'

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's version here and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# A good docstring documents *guarantees* — things the caller can rely on. Before writing your prompt, make three decisions:
#
# 1. What happens if `score` is negative or above 100? Does the function guarantee anything?
# 2. Does the function accept floats (e.g. 89.7) or only integers?
# 3. Is the 90/80/70/60 cutoff scheme itself documented, or left implicit?
#
# Write a prompt that tells Claude your answers and asks it to write a docstring that reflects them.

# %% [markdown]
# **My decisions:**
#
# 1. Out-of-range scores:
# 2. Float vs integer:
# 3. Cutoff scheme:
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste the best version here and run it

# %% [markdown]
# **Reflection:** Read the docstring from the lazy prompt. What does a future teammate *not* know after reading it that they would need to know? Does your directed version close those gaps?
#
# ---

# %% [markdown]
# ## Exercise 5 — Debug This Code
#
# **The problem:** This function is supposed to return the average of a list of numbers. It has at least one bug — possibly more.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt with the function.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Fix this code."

# ── Code to paste along with the prompt ──────────────────────────────────
def average(numbers):
    total = 0
    for n in numbers:
        total = total + n
    return total / len(numbers)
    total = 0

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's fixed code and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "This Python function should take a list of numbers and return their average as a float.
#  Find every bug, explain each one in plain English, and return a corrected version.
#  Also show what happens when the list is empty."

# ── Code to paste along with the prompt ──────────────────────────────────
def average(numbers):
    total = 0
    for n in numbers:
        total = total + n
    return total / len(numbers)
    total = 0

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's fixed code and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# Read the code slowly before you do anything else. Answer these questions yourself first:
#
# 1. There is a line of dead code that can never run. Which line, and why?
# 2. What happens when `numbers = []`? Trace through the code step by step.
# 3. Decide: when called with an empty list, should the function return `0.0`, return `None`, or raise a `ValueError`?
#
# Now write a prompt that shares your answers to 1 and 2, states your decision for 3, and asks Claude to confirm your analysis and fix the function to match your decision.

# %% [markdown]
# **My analysis:**
#
# 1. Dead code:
# 2. Empty list trace:
# 3. My decision:
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and test the fixed function here
# average([10, 20, 30]) should return 20.0
# average([5]) should return 5.0
# average([]) — test your decision here

# %% [markdown]
# **Reflection:** Did spotting the bug yourself *before* prompting change the conversation? When you told Claude what you already found, did it confirm, correct, or extend your analysis?
#
# ---

# %% [markdown]
# ## Exercise 6 — Explain a Concept at the Right Level
#
# **The problem:** Get Claude to explain recursion in a way that actually sticks.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt exactly.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Explain recursion."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# No code to run — paste any example code Claude provides here

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Explain recursion to a student who understands Python for-loops and functions
#  but has never seen a function call itself. Use a single short Python example
#  (10 lines or fewer). Explain what happens step by step when the function runs.
#  Keep the whole explanation under 150 words."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste any example code here and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# The lazy response was probably long and abstract. The better response was shorter and concrete. Now make it *yours* — craft a prompt that forces Claude to explain recursion through a specific framing that you choose.
#
# **Before prompting, decide:**
# 1. Pick a real-world process that is naturally recursive — something that repeats a smaller version of itself until a simple case is reached. (Example domains: organizational hierarchies, folder structures, loan amortization, supply chains.)
# 2. Decide what the *base case* is in your analogy — the point where the repetition stops.
# 3. Decide what warning you want Claude to include about what can go wrong.
#
# Write a prompt that names your analogy, states the base case, requests a Python example using it, and asks for the warning.

# %% [markdown]
# **My analogy and base case:**
#
# **My warning topic:**
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste any code from Claude's response here and run it

# %% [markdown]
# **Reflection:** Three people with the same Attempt 3 prompt will get three completely different explanations — and all three might be excellent. What does that tell you about who is really directing the output?
#
# ---

# %% [markdown]
# ## Exercise 7 — Generate Test Cases
#
# **The problem:** Write test cases for this BMI function.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt with the function.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Write test cases for this function."

# ── Function to paste along with the prompt ───────────────────────────────
def bmi(weight_kg, height_m):
    return weight_kg / (height_m ** 2)

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's tests here and run them

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Write pytest test cases for this BMI function. Cover:
#  - a typical adult (normal BMI result)
#  - a result that falls in each WHO category: underweight (<18.5), normal (18.5–24.9),
#    overweight (25–29.9), obese (≥30)
#  - height = 0 (currently causes a crash)
#  - negative weight
#  Use assert statements with approximate float comparisons where needed."

# ── Function to paste along with the prompt ───────────────────────────────
def bmi(weight_kg, height_m):
    return weight_kg / (height_m ** 2)

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste Claude's tests here and run them

# %% [markdown]
# ### Attempt 3 — Directed prompt
# The current `bmi` function has no input validation — it will return a nonsensical negative number for negative weight, and crash with ZeroDivisionError for height = 0. Before prompting, make a firm decision:
#
# **Decision required:** Should `bmi` be modified to raise a `ValueError` for invalid inputs (negative weight, zero or negative height), or should the tests simply *document* that the current behavior is a crash/wrong answer — a 'known bug' test?
#
# Write a prompt that states your decision and asks Claude to:
# 1. Modify `bmi` to enforce your decision (or not, if you chose the 'document the bug' approach)
# 2. Write tests that *prove* the function behaves according to your decision

# %% [markdown]
# **My decision on invalid inputs:**
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and run the tests here

# %% [markdown]
# **Reflection:** Tests are not just checks — they are *documented decisions*. A test that says `pytest.raises(ValueError)` tells every future developer: 'we decided this is illegal input.' Did making the decision before prompting produce a more useful test suite?
#
# ---

# %% [markdown]
# ## Exercise 8 — Plan a Small Project
#
# **The problem:** Use Claude to help build a grade calculator.
#
# ### Attempt 1 — Lazy prompt
# Copy this prompt exactly.

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Help me build a grade calculator in Python."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste any code Claude provides and run it

# %% [markdown]
# ### Attempt 2 — Better prompt

# %%
# ── PROMPT ───────────────────────────────────────────────────────────────
# "Help me design a Python grade calculator. It takes a list of (score, weight) tuples
#  where scores are 0–100 floats and weights are decimals that sum to 1.0.
#  It computes the weighted average and returns a letter grade (A/B/C/D/F).
#  Give me only the function signatures and example calls — no implementation yet.
#  I want to review the design before writing any code."

# %% [markdown]
# *Paste Claude's response here, then run the code cell below.*

# %%
# Paste any code Claude provides and run it

# %% [markdown]
# ### Attempt 3 — Directed prompt
# A real project has constraints that Claude cannot know unless you state them. Before prompting, complete this design sketch:
#
# **Design questions to answer first:**
# 1. Inputs: what Python type holds each score and its weight? (list of tuples? two separate lists? a dict?)
# 2. What happens if the weights don't sum to 1.0 — normalize silently, raise an error, or warn and continue?
# 3. What happens if a score is missing for one assignment — skip it, count it as 0, or raise an error?
# 4. One function or several? (e.g. separate `weighted_average` and `letter_grade` functions?)
# 5. Should the implementation include a `main` block that demonstrates usage?
#
# Write a prompt that captures all five decisions and asks Claude to implement — not just design — the full calculator.

# %% [markdown]
# **My design sketch:**
#
# 1. Input structure:
# 2. Weights don't sum to 1.0:
# 3. Missing score:
# 4. One function or several:
# 5. Demo block:
#
# **My prompt:**
#
# **Claude's response:**

# %%
# Paste and test the implementation here

# %% [markdown]
# **Reflection:** Compare the lazy response to your directed one. The lazy version probably works for a demo. Would you hand it to a teammate to maintain? What would they need to ask you before they could safely modify it?
#
# ---
#
# ## Class Takeaway
#
# Complete this sentence in your own words:
#
# > *The quality of AI output is determined by...*
#
# ---
#
# > **The pattern across all eight exercises:**
# > Lazy prompts get working-ish code.
# > Better prompts get code that matches the spec.
# > Directed prompts get code that reflects *your decisions* — which means you can read it, trust it, and explain it.
