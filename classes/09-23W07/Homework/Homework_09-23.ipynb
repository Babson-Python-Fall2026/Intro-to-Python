# %% [markdown]
# # OIM3600 — Homework
# ## Python Foundations — Sections 7–11
#
# **Target time:** about 2 hours
# **Sections:**
# - 7 — Tuples
# - 8 — Dictionaries
# - 9 — Three Ways to Talk to an Object
# - 10 — Variables, References, and Aliasing
# - 11 — Mutability, Rebinding, and Copying
#
# This homework comes **after** the Sections 7–11 in-class exercises.
#
# The goal is not to repeat the class notebook. Instead, you will apply the ideas in **new situations**, connect concepts across sections, diagnose code, explain why Python behaves the way it does, and practice researching an unfamiliar technical topic.
#
# ## How to work
#
# For prediction questions:
#
# 1. Write your prediction **before running the code**.
# 2. If your prediction is wrong, **do not erase it**.
# 3. Add the actual result and explain what you misunderstood.
#
# For code questions:
#
# - Add code only where instructed.
# - Prefer clear reasoning over clever one-line answers.
# - Use small experiments when uncertain.
#
# ### AI use
#
# You may use your OIM3600 Project AI as a **syntax/reference and explanation tool**.
#
# Do not ask AI to simply complete the homework for you. Your submitted work should show your own reasoning and understanding.

# %% [markdown]
# ## Suggested pacing
#
# | Problem | Focus | Time |
# |---|---|---:|
# | 1 | Choosing tuples, lists, and dictionaries | 8 min |
# | 2 | Tuple keys and dictionary lookup | 8 min |
# | 3 | `.get()` and missing data | 8 min |
# | 4 | Nested business data | 10 min |
# | 5 | Read the syntax: brackets, methods, functions | 8 min |
# | 6 | Reference tracing in a new context | 10 min |
# | 7 | Diagnose mutation vs rebinding | 10 min |
# | 8 | Function behavior | 10 min |
# | 9 | Copying nested data | 10 min |
# | 10 | Integrated challenge | 12 min |
# | 11 | Researching password protection | 25 min |
#
# **Total:** about 119 minutes — roughly 2 hours at a careful pace.

# %% [markdown]
# ---
# ## Problem 1 — Choose the right representation
# **Sections 7–8 · About 8 minutes**
#
# A travel company needs to represent several different kinds of information.
#
# Think about which collection type best matches each situation. Useful ideas include:
#
# - fixed grouping
# - mutability
# - ordered sequence
# - lookup by meaningful key
#
# Complete the choices and explanations in the code cell below.

# %%
# For each item, choose tuple, list, or dictionary.
# Then explain your choice in one sentence.

# 1. A fixed airport code pair such as ("BOS", "GCM")
route = None
# Explanation:


# 2. A traveler's list of planned activities
activities = None
# Explanation:


# 3. A mapping from activity name to price
prices = None
# Explanation:


# 4. A calendar date such as (2027, 1, 12)
travel_date = None
# Explanation:

# Replace each None with your choice.

# %% [markdown]
# ---
# ## Problem 2 — Tuple keys
# **Sections 7–8 · About 8 minutes**
#
# A ferry company charges different prices for different origin/destination pairs:
#
# ```python
# fares = {
#     ("Boston", "Provincetown"): 72,
#     ("Boston", "Salem"): 38,
#     ("Salem", "Provincetown"): 61
# }
# ```
#
# Use what you know about dictionary keys, mutability, and lookup to answer the questions in the code cell below.

# %%
fares = {
    ("Boston", "Provincetown"): 72,
    ("Boston", "Salem"): 38,
    ("Salem", "Provincetown"): 61
}

# 1. Why is a tuple a reasonable key here?
# Answer:


# 2. Write the expression that retrieves the Boston -> Salem fare.
# Answer:
# print(...)


# 3. Before running it, predict what happens if you try to use
#    ["Boston", "Salem"] as a key.
# Prediction:


# 4. Explain why Python rejects the list key in terms of mutability.
# Answer:


# After predicting, you may test why this fails:
# print(fares[["Boston", "Salem"]])

# %% [markdown]
# ---
# ## Problem 3 — `.get()` does not add anything
# **Section 8 · About 8 minutes**
#
# A store keeps inventory counts:
#
# ```python
# inventory = {
#     "keyboard": 12,
#     "mouse": 20
# }
# ```
#
# The store wants to look up an item that may not yet be in the dictionary. Answer the questions in the code cell before running it.

# %%
inventory = {
    "keyboard": 12,
    "mouse": 20
}

# BEFORE RUNNING:

# 1. Predict the value stored in count after:
#    count = inventory.get("monitor", 0)
# Prediction:


# 2. Will "monitor" now be a key in inventory?
# Prediction:


# 3. How would you explicitly add "monitor": 0 to inventory?
# Answer:


# 4. Explain the difference between each expression:
#    inventory["monitor"]
# Answer:

#    inventory.get("monitor")
# Answer:

#    inventory.get("monitor", 0)
# Answer:


count = inventory.get("monitor", 0)

print("count:", count)
print("inventory:", inventory)

# Add monitor explicitly below.
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Problem 4 — Navigate nested business data
# **Section 8 · About 10 minutes**
#
# Use this structure:
#
# ```python
# client = {
#     "name": "Apex LLC",
#     "account": (2026, 1042),
#     "positions": [
#         {"ticker": "AAPL", "shares": 10},
#         {"ticker": "MSFT", "shares": 5}
#     ],
#     "preferences": {
#         "risk": "moderate",
#         "alerts": ["email", "text"]
#     }
# }
# ```
#
# Practice tracing through nested collections one lookup at a time. Complete the six retrievals in the code cell below and count the lookups for each one.

# %%
client = {
    "name": "Apex LLC",
    "account": (2026, 1042),
    "positions": [
        {"ticker": "AAPL", "shares": 10},
        {"ticker": "MSFT", "shares": 5}
    ],
    "preferences": {
        "risk": "moderate",
        "alerts": ["email", "text"]
    }
}

# 1. Retrieve "Apex LLC".
# Expression:
# Number of lookups:


# 2. Retrieve 1042.
# Expression:
# Number of lookups:


# 3. Retrieve the entire positions list.
# Expression:
# Number of lookups:


# 4. Retrieve "MSFT".
# Expression:
# Number of lookups:


# 5. Retrieve the number of MSFT shares.
# Expression:
# Number of lookups:


# 6. Retrieve "text".
# Expression:
# Number of lookups:


# Print each expression below to verify your answers.

# %% [markdown]
# ---
# ## Problem 5 — Read the syntax, then explain the behavior
# **Section 9 · About 8 minutes**
#
# Python gives us several different ways to interact with objects.
#
# Use these labels:
#
# - **B** — bracket lookup
# - **M** — method call
# - **F** — function call
#
# Remember: syntax and mutability are related ideas, but they are **not the same question**. A method call, for example, may or may not mutate its object.
#
# Classify the expressions in the code cell below.

# %%
# For each line:
#   1. Label it B (bracket lookup), M (method call), or F (function call).
#   2. State whether the line could mutate the object involved.

# 1. client["name"]
# Label:
# Could mutate? Why or why not?


# 2. client["positions"].append({"ticker": "GOOG", "shares": 2})
# Label:
# Could mutate? Why or why not?


# 3. len(client["positions"])
# Label:
# Could mutate? Why or why not?


# 4. client.get("cash", 0)
# Label:
# Could mutate? Why or why not?


# 5. sorted(client["preferences"]["alerts"])
# Label:
# Could mutate? Why or why not?


# Use the space below for any small experiments you need.

# %% [markdown]
# ---
# ## Problem 6 — Reference tracing in a new context
# **Section 10 · About 10 minutes**
#
# Study this setup:
#
# ```python
# original = {"AAPL": 10, "MSFT": 5}
# working = original
# snapshot = {"AAPL": 10, "MSFT": 5}
#
# working["AAPL"] = 12
# ```
#
# Trace the names and objects carefully. Write all predictions in the code cell before running it.

# %%
# BEFORE RUNNING, write your predictions.

# 1. What will original contain?
# Prediction:


# 2. What will working contain?
# Prediction:


# 3. What will snapshot contain?
# Prediction:


# 4. Is original == snapshot?
# Prediction:


# 5. Is original is snapshot?
# Prediction:


# 6. Is original is working?
# Prediction:


# 7. How many dictionary objects exist?
# Prediction:


original = {"AAPL": 10, "MSFT": 5}
working = original
snapshot = {"AAPL": 10, "MSFT": 5}

working["AAPL"] = 12

print("original:", original)
print("working:", working)
print("snapshot:", snapshot)

print("original == snapshot:", original == snapshot)
print("original is snapshot:", original is snapshot)
print("original is working:", original is working)

# %% [markdown]
# If your prediction was wrong, draw the names and objects as arrows.
#
# Use:
#
# ```text
# name  ──► object
# ```

# %% [markdown]
# ---
# ## Problem 7 — Diagnose mutation vs rebinding
# **Section 11 · About 10 minutes**
#
# Two programmers try to add `"GOOG"` to a portfolio.
#
# ### Version A
#
# ```python
# portfolio = ["AAPL", "MSFT"]
# watchlist = portfolio
# watchlist.append("GOOG")
# ```
#
# ### Version B
#
# ```python
# portfolio = ["AAPL", "MSFT"]
# watchlist = portfolio
# watchlist = watchlist + ["GOOG"]
# ```
#
# Although both versions appear to “add GOOG,” they do not behave the same way. Analyze both versions in the code cell below.

# %%
# VERSION A — BEFORE RUNNING
# 1. Predict portfolio:
# 2. Predict watchlist:
# 3. Predict portfolio is watchlist:
# 4. Is the key operation mutation or rebinding?

# Test Version A below.


# VERSION B — BEFORE RUNNING
# 1. Predict portfolio:
# 2. Predict watchlist:
# 3. Predict portfolio is watchlist:
# 4. Is the key operation mutation or rebinding?

# Test Version B below.


# 5. Explain why the two versions behave differently even though
#    both appear to "add GOOG."
# Answer:

# %% [markdown]
# ---
# ## Problem 8 — Functions: what can escape the local scope?
# **Sections 10–11 · About 10 minutes**
#
# Study these two functions:
#
# ```python
# def update_a(data):
#     data["status"] = "reviewed"
#
# def update_b(data):
#     data = {"status": "reviewed"}
# ```
#
# Both functions receive a reference to an object through the parameter `data`, but the function bodies do different things. Make your predictions and explain the difference in the code cell below.

# %%
# BEFORE RUNNING

# 1. Predict the dictionary printed after update_a(record).
# Prediction:


# 2. Predict the dictionary printed after update_b(record).
# Prediction:


# 3. In each function, is data a local name?
# Answer:


# 4. When each function begins, does data refer to the same object as record?
# Answer:


# 5. Which function mutates the shared object?
# Answer:


# 6. Which function only rebinds the local name?
# Answer:


# 7. Why does only one function affect the caller's dictionary?
# Answer:


def update_a(data):
    data["status"] = "reviewed"

def update_b(data):
    data = {"status": "reviewed"}

record = {"status": "new"}
update_a(record)
print("after update_a:", record)

record = {"status": "new"}
update_b(record)
print("after update_b:", record)

# %% [markdown]
# ---
# ## Problem 9 — When a copy is not fully independent
# **Section 11 · About 10 minutes**
#
# A manager wants a backup before editing employee project assignments:
#
# ```python
# employees = [
#     {"name": "Ana", "projects": ["Website", "Forecast"]},
#     {"name": "Ben", "projects": ["Hiring"]}
# ]
#
# backup = employees.copy()
# backup[0]["projects"].append("AI")
# ```
#
# A shallow copy creates a new outer list, but that does not necessarily make all nested objects independent. Analyze what is shared in the code cell below.

# %%
# BEFORE RUNNING

# 1. Is employees is backup true or false?
# Prediction:


# 2. Is employees[0] is backup[0] true or false?
# Prediction:


# 3. Will "AI" appear inside employees?
# Prediction:


# 4. Why?
# Answer:


# 5. What kind of copy would create a fully independent nested structure?
# Answer:


employees = [
    {"name": "Ana", "projects": ["Website", "Forecast"]},
    {"name": "Ben", "projects": ["Hiring"]}
]

backup = employees.copy()
backup[0]["projects"].append("AI")

print("employees:", employees)
print("backup:", backup)

print("same outer list?", employees is backup)
print("same first dictionary?", employees[0] is backup[0])
print("same projects list?", employees[0]["projects"] is backup[0]["projects"])

# %% [markdown]
# After you understand the result, rewrite the setup using `copy.deepcopy()` and verify that editing the backup no longer changes the original.

# %%
import copy

# Write your deep-copy version here.

# %% [markdown]
# ---
# ## Problem 10 — Integrated challenge: represent, update, preserve
# **Sections 7–11 · About 12 minutes**
#
# A student registration system needs to represent one student with:
#
# - student ID `1042`
# - name `"Jordan Lee"`
# - date of birth `(2007, 5, 26)`
# - courses `["OIM3600", "ACC3500"]`
# - grades:
#   - OIM3600 → 92
#   - ACC3500 → 88
#
# This problem combines representation, nested collections, mutation, lookup, and copying. Complete Parts A–E in the code cell below.

# %%
import copy

# Part A — Representation
# Create one object named student using tuples, lists, and dictionaries
# where appropriate. Be ready to justify each collection type.
student = {
    # YOUR CODE HERE
}


# Part B — Snapshot
# Create a fully independent snapshot named original_student.
# original_student = ...


# Part C — Update
# Change the student's OIM3600 grade to 95.
# Add "FIN3520" to the course list.
# YOUR CODE HERE


# Part D — Verify
# Print both objects and prove that student changed but original_student did not.
# print(...)


# Part E — Explain in comments
# 1. Identify one bracket lookup you used.
# Answer:

# 2. Identify one mutation you performed.
# Answer:

# 3. Identify one function call you used.
# Answer:

# 4. Why is a deep copy safer here than a shallow copy?
# Answer:

# %% [markdown]
# ---
# ## Problem 11 — Research: How should passwords be protected?
# **Research practice · About 25 minutes**
#
# Everyone is familiar with passwords, but protecting stored passwords requires ideas you may not have seen before.
#
# Imagine that you are building a program that will store user information in a file. You already know that storing each user's actual password in that file would be dangerous.
#
# Your goal in this problem is **not to write Python code**. Your goal is to practice researching an unfamiliar technical problem, deciding which sources are trustworthy, and explaining what you learned clearly.
#
# Use **at least two reliable non-AI sources**. You may use AI to help you understand terminology, but AI should not be your only source. Answer in your own words in the code cell below.

# %%
# RESEARCH — DO NOT WRITE PYTHON CODE FOR THIS PROBLEM.
# Write your answers as comments.

# 1. Why should a program not store a user's actual password in a file?
# Answer:


# 2. What is password hashing? How is hashing different from encryption?
# Answer:


# 3. What is a salt? Why is a salt used when passwords are hashed?
# Answer:


# 4. Python has both the random and secrets modules.
#    Why is random generally inappropriate for security-related values,
#    and what is secrets designed to do?
# Answer:


# 5. If the program never stores the original password, how can it later
#    determine whether the user entered the correct password?
# Answer:


# 6. List the sources you used. For each source, briefly explain why you
#    considered it trustworthy.
# Sources and explanation:

# %% [markdown]
# ---
# ## Final reflection
#
# Use the final code cell to connect the ideas from Sections 10–11. Write 3–5 sentences.

# %%
# FINAL REFLECTION — write 3–5 sentences as comments.

# Why is "variables are labels that refer to objects" a more useful mental
# model than "variables are boxes that contain values"?
#
# Mention at least two of these ideas:
# - aliasing
# - mutation
# - rebinding
# - function parameters
# - copying

# Answer:
